# %%
pip install transformers torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 63.0 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.8/558.8 kB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 96.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 98.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 0.29.2
#     Uninstalling huggingface_hub-0.29.2:
#       Successfully uninstalled huggingface_hub-0.29.2
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# This should already be available in your IBM Cloud kernel
model_id = "ibm/granite-7b-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float32)  # or float16 on GPU
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/ibm/granite-7b-instruct/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...

# %%
from instructlab.model import load_model, generate

model, tokenizer = load_model("granite-7b-instruct")

prompt = """Your startup blueprint prompt here..."""

result = generate(model, tokenizer, prompt, max_new_tokens=500)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from instructlab.model import load_model, generate
#       3 model, tokenizer = load_model("granite-7b-instruct")
#       5 prompt = """Your startup blueprint prompt here..."""
#
# ModuleNotFoundError: No module named 'instructlab'

# %%
# !pip list | grep instructlab

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 48.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.5/324.5 kB 53.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 101.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 101.7 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: brotli
#     Found existing installation: Brotli 1.0.9
#     Uninstalling Brotli-1.0.9:
#       Successfully uninstalled Brotli-1.0.9
# ...

# %%
import gradio as gr

def generate(domain, audience, budget, timeline, country):
    prompt = f"""
Generate a startup blueprint for:
- Domain: {domain}
- Audience: {audience}
- Budget: {budget}
- Country: {country}
- Timeline: {timeline}

Respond with 1. Problem, 2. Solution, 3. MVP, etc.
    """
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_new_tokens=400)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

gr.Interface(
    fn=generate,
    inputs=["text", "text", "text", "text", "text"],
    outputs="text",
    title="Startup Blueprint Generator",
    description="Enter details and get a blueprint powered by AI"
).launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
